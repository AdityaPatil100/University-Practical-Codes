# %% [markdown]
# # Assignment no:2

# %%
import pandas as pd

# %%
import numpy as np

# %%
import matplotlib.pyplot as plt

# %%
from scipy import stats

# %%
df=pd.read_csv("StudentsPerformance.csv")

# %%
df.head()
# Out:
#    Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0        80.0           90.0           70.0               77            2018
# 1        70.0           77.0           76.0               85            2018
# 2        62.0           88.0           68.0               92            2019
# 3        94.0           84.0           71.0               78            2019
# 4        78.0           81.0           62.0              100            2020
#
#    Placement_Offer_Count
# 0                      2
# 1                      3
# 2                      3
# 3                      2
# 4                      3

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# ...

# %%
df.tail()
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 25        76.0           83.0           79.0               77            2019
# 26        68.0           87.0           76.0               95            2020
# 27        61.0           75.0           63.0               93            2020
# 28        80.0            NaN           61.0              100            2020
# 29        65.0           78.0           73.0               98            2018
#
#     Placement_Offer_Count
# 25                      2
# 26                      3
# 27                      3
# 28                      3
# 29                      3

# %%
df.shape
# Out:
# (30, 6)

# %%
df.dtypes
# Out:
# Math_score               float64
# Reading_score            float64
# Writing_score            float64
# Placement_score            int64
# Club_Join_Date             int64
# Placement_Offer_Count      int64
# dtype: object

# %%
df.isnull()
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0        False          False          False            False           False
# 1        False          False          False            False           False
# 2        False          False          False            False           False
# 3        False          False          False            False           False
# 4        False          False          False            False           False
# 5        False          False          False            False           False
# 6        False          False          False            False           False
# 7        False          False          False            False           False
# 8        False          False          False            False           False
# 9        False          False          False            False           False
# 10       False          False          False            False           False
# ...

# %%
df.isnull().sum()
# Out:
# Math_score               1
# Reading_score            1
# Writing_score            1
# Placement_score          0
# Club_Join_Date           0
# Placement_Offer_Count    0
# dtype: int64

# %%
series=pd.isnull(df["Math_score"])

# %%
df[series]
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 24         NaN           81.0           66.0               81            2019
#
#     Placement_Offer_Count
# 24                      2

# %%
df.notnull()
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         True           True           True             True            True
# 1         True           True           True             True            True
# 2         True           True           True             True            True
# 3         True           True           True             True            True
# 4         True           True           True             True            True
# 5         True           True           True             True            True
# 6         True           True           True             True            True
# 7         True           True           True             True            True
# 8         True           True           True             True            True
# 9         True           True           True             True            True
# 10        True           True           True             True            True
# ...

# %%
df.describe()
# Out:
#        Math_score  Reading_score  Writing_score  Placement_score  \
# count   29.000000      29.000000      29.000000        30.000000
# mean    75.103448      88.068966      69.620690        85.633333
# std     21.699810      22.238851       5.734693         8.833648
# min     61.000000      75.000000      61.000000        75.000000
# 25%     65.000000      80.000000      64.000000        77.250000
# 50%     70.000000      83.000000      70.000000        82.000000
# 75%     78.000000      90.000000      74.000000        93.000000
# max    180.000000     200.000000      79.000000       100.000000
#
#        Club_Join_Date  Placement_Offer_Count
# count       30.000000              30.000000
# mean      2019.466667               2.433333
# std          0.899553               0.568321
# min       2018.000000               1.000000
# 25%       2019.000000               2.000000
# 50%       2020.000000               2.000000
# 75%       2020.000000               3.000000
# ...

# %%
df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# ...

# %%
df1=df

# %%
df1.fillna(0)
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# ...

# %%
df2=df

# %%
df2["Math_score"]=df2["Math_score"].fillna(df2["Math_score"].mean())

# %%
df2
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    80.000000           90.0           70.0               77            2018
# 1    70.000000           77.0           76.0               85            2018
# 2    62.000000           88.0           68.0               92            2019
# 3    94.000000           84.0           71.0               78            2019
# 4    78.000000           81.0           62.0              100            2020
# 5    77.000000          200.0           73.0               82            2020
# 6    77.000000           75.0           65.0              100            2020
# 7    62.000000           80.0           63.0               97            2019
# 8    79.000000           88.0           65.0               82            2018
# 9    63.000000           94.0           73.0               79            2021
# 10   66.000000           79.0           77.0               80            2019
# ...

# %%
col=["Math_score","Reading_score","Writing_score","Placement_score"]

# %%
df.boxplot(col)
# Out:
# <AxesSubplot:>

# %%
new_df=pd.read_csv("StudentsPerformance.csv")

# %%
new_df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0         80.0           90.0           70.0               77            2018
# 1         70.0           77.0           76.0               85            2018
# 2         62.0           88.0           68.0               92            2019
# 3         94.0           84.0           71.0               78            2019
# 4         78.0           81.0           62.0              100            2020
# 5         77.0          200.0           73.0               82            2020
# 6         77.0           75.0           65.0              100            2020
# 7         62.0           80.0           63.0               97            2019
# 8         79.0           88.0           65.0               82            2018
# 9         63.0           94.0           73.0               79            2021
# 10        66.0           79.0           77.0               80            2019
# ...

# %%
print(np.where(new_df["Math_score"]>90))
# Out:
# (array([ 3, 17], dtype=int64),)

# %%
mean1=np.mean(df["Math_score"])

# %%
mean1
# Out:
# 75.10344827586208

# %%
z=stats.zscore(df["Math_score"])

# %%
z
# Out:
# 0     2.335694e-01
# 1    -2.434386e-01
# 2    -6.250450e-01
# 3     9.013807e-01
# 4     1.381678e-01
# 5     9.046704e-02
# 6     9.046704e-02
# 7    -6.250450e-01
# 8     1.858686e-01
# 9    -5.773442e-01
# 10   -4.342418e-01
# 11   -2.911394e-01
# 12    2.335694e-01
# 13   -4.342418e-01
# 14   -5.296434e-01
# 15    1.381678e-01
# 16   -6.727458e-01
# 17    5.003650e+00
# 18    2.335694e-01
# 19   -2.434386e-01
# 20   -2.911394e-01
# 21   -1.957378e-01
# 22   -1.957378e-01
# 23   -6.727458e-01
# 24   -6.778692e-16
# 25    4.276624e-02
# 26   -3.388402e-01
# 27   -6.727458e-01
# 28    2.335694e-01
# 29   -4.819426e-01
# Name: Math_score, dtype: float64

# %%
threshold=3

# %%
sample_outliers = np.where(z>threshold)

# %%
sample_outliers
# Out:
# (array([17], dtype=int64),)

# %%
Q1=df.Math_score.quantile(0.25)

# %%
Q1
# Out:
# 65.25

# %%
Q3=df.Math_score.quantile(0.75)

# %%
Q3
# Out:
# 78.0

# %%
IQR=Q3-Q1

# %%
IQR
# Out:
# 12.75

# %%
lower_limit=Q1-1.5*IQR
upper_limit=Q3+1.5*IQR
lower_limit,upper_limit
# Out:
# (46.125, 97.125)

# %%
df[(df.Math_score<lower_limit)|(df.Math_score>upper_limit)]
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 17       180.0           82.0           76.0               95            2019
#
#     Placement_Offer_Count
# 17                      3

# %%
sample_outliers1=df["Math_score"][(df["Math_score"]>upper_limit)|(df["Math_score"]<lower_limit)]

# %%
sample_outliers1
# Out:
# 17    180.0
# Name: Math_score, dtype: float64

# %%
index_outliers=np.where((df.Math_score<lower_limit)|(df.Math_score>upper_limit))

# %%
index_outliers
# Out:
# (array([17], dtype=int64),)

# %%
redefined_df=df2

# %%
redefined_df["Math_score"]=np.where((redefined_df["Math_score"]>upper_limit),mean1,redefined_df["Math_score"])

# %%
redefined_df
# Out:
#     Math_score  Reading_score  Writing_score  Placement_score  Club_Join_Date  \
# 0    80.000000           90.0           70.0               77            2018
# 1    70.000000           77.0           76.0               85            2018
# 2    62.000000           88.0           68.0               92            2019
# 3    94.000000           84.0           71.0               78            2019
# 4    78.000000           81.0           62.0              100            2020
# 5    77.000000          200.0           73.0               82            2020
# 6    77.000000           75.0           65.0              100            2020
# 7    62.000000           80.0           63.0               97            2019
# 8    79.000000           88.0           65.0               82            2018
# 9    63.000000           94.0           73.0               79            2021
# 10   66.000000           79.0           77.0               80            2019
# ...

# %%
col1=["Math_score"]

# %%
redefined_df.boxplot("Math_score")
# Out:
# <AxesSubplot:>

# %%
plt.show()

# %%
redefined_df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
df.plot(kind="bar")
# Out:
# <AxesSubplot:>

# %%
plt.show()

# %%
import pandas as pd

# %%
import numpy as np

# %%
df3=pd.read_csv("Height1.csv")

# %%
df3
# Out:
#       Name  Height
# 0   Aditya     5.9
# 1   Sumedh     5.2
# 2    Parag     5.1
# 3   Gaurav     5.5
# 4  Vaibhav     4.9
# 5   Rutwik     5.4
# 6     Yash     6.2
# 7    Sagar     6.5
# 8   Chetan     7.1
# 9      Jay    14.5

# %%
df3.shape
# Out:
# (10, 2)

# %%
df3["Name"]
# Out:
# 0     Aditya
# 1     Sumedh
# 2      Parag
# 3     Gaurav
# 4    Vaibhav
# 5     Rutwik
# 6       Yash
# 7      Sagar
# 8     Chetan
# 9        Jay
# Name: Name, dtype: object

# %%
df3["Height"]
# Out:
# 0     5.9
# 1     5.2
# 2     5.1
# 3     5.5
# 4     4.9
# 5     5.4
# 6     6.2
# 7     6.5
# 8     7.1
# 9    14.5
# Name: Height, dtype: float64

# %%
df3['Height'].quantile(0.95)
# Out:
# 11.169999999999991

# %%
max_thresold=df3["Height"].quantile(0.95)

# %%
max_thresold
# Out:
# 11.169999999999991

# %%
df3[df3["Height"]>max_thresold]
# Out:
#   Name  Height
# 9  Jay    14.5

# %%
min_thresold=df3["Height"].quantile(0.5)

# %%
min_thresold
# Out:
# 5.7

# %%
df3[df3["Height"]<min_thresold]
# Out:
#       Name  Height
# 1   Sumedh     5.2
# 2    Parag     5.1
# 3   Gaurav     5.5
# 4  Vaibhav     4.9
# 5   Rutwik     5.4

# %%
df3[(df3["Height"]<max_thresold)& (df3["Height"]>min_thresold)]
# Out:
#      Name  Height
# 0  Aditya     5.9
# 6    Yash     6.2
# 7   Sagar     6.5
# 8  Chetan     7.1

# %%
plt.show()
